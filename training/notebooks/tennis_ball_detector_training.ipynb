# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting roboflow
#   Downloading roboflow-1.1.53-py3-none-any.whl.metadata (9.7 kB)
# Collecting certifi (from roboflow)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting cycler (from roboflow)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting kiwisolver>=1.3.1 (from roboflow)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting matplotlib (from roboflow)
#   Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=1.18.5 (from roboflow)
#   Downloading numpy-2.2.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading pillow-11.1.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: python-dateutil in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting requests (from roboflow)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.17.0)
# Collecting urllib3>=1.26.6 (from roboflow)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting PyYAML>=5.3.1 (from roboflow)
#   Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: colorama in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Collecting contourpy>=1.0.1 (from matplotlib->roboflow)
#   Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->roboflow)
#   Downloading fonttools-4.55.8-cp313-cp313-win_amd64.whl.metadata (103 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib->roboflow) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib->roboflow)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->roboflow)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Downloading roboflow-1.1.53-py3-none-any.whl (82 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ----- ---------------------------------- 5.2/38.8 MB 27.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.0/38.8 MB 27.6 MB/s eta 0:00:02
#    ------------------ --------------------- 18.1/38.8 MB 30.2 MB/s eta 0:00:01
#    ------------------------ --------------- 24.1/38.8 MB 29.6 MB/s eta 0:00:01
#    ------------------------------ --------- 29.9/38.8 MB 29.3 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.8 MB 28.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 28.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading numpy-2.2.2-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------------- ---------------------- 5.5/12.6 MB 26.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 28.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 29.0 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 31.4 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------------------------------- ------ 6.8/8.0 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 32.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl (102 kB)
# Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Downloading fonttools-4.55.8-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 35.4 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: filetype, urllib3, tqdm, PyYAML, python-dotenv, pyparsing, Pillow, numpy, kiwisolver, idna, fonttools, cycler, charset-normalizer, certifi, requests, opencv-python-headless, contourpy, requests-toolbelt, matplotlib, roboflow
# Successfully installed Pillow-11.1.0 PyYAML-6.0.2 certifi-2025.1.31 charset-normalizer-3.4.1 contourpy-1.3.1 cycler-0.12.1 filetype-1.2.0 fonttools-4.55.8 idna-3.7 kiwisolver-1.4.8 matplotlib-3.10.0 numpy-2.2.2 opencv-python-headless-4.10.0.84 pyparsing-3.2.1 python-dotenv-1.0.1 requests-2.32.3 requests-toolbelt-1.0.0 roboflow-1.1.53 tqdm-4.67.1 urllib3-2.3.0
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting ultralytics
#   Downloading ultralytics-8.3.70-py3-none-any.whl.metadata (35 kB)
# Collecting numpy<=2.1.1,>=1.23.0 (from ultralytics)
#   Downloading numpy-2.1.1-cp313-cp313-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (3.10.0)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (2.32.3)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.15.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.6.0-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.21.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from ultralytics) (6.1.1)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting setuptools (from torch>=1.8.0->ultralytics)
#   Downloading setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Downloading ultralytics-8.3.70-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    --------------------------------------- 914.9/914.9 kB 39.1 MB/s eta 0:00:00
# Downloading numpy-2.1.1-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------------------- ------------------ 6.8/12.6 MB 33.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 35.7 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ----- ---------------------------------- 5.0/39.5 MB 26.3 MB/s eta 0:00:02
#    ------ --------------------------------- 6.6/39.5 MB 15.9 MB/s eta 0:00:03
#    ------- -------------------------------- 7.9/39.5 MB 13.4 MB/s eta 0:00:03
#    ------- -------------------------------- 7.9/39.5 MB 13.4 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/39.5 MB 9.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.0/39.5 MB 9.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.8/39.5 MB 8.3 MB/s eta 0:00:04
#    ------------- -------------------------- 12.8/39.5 MB 7.9 MB/s eta 0:00:04
#    -------------- ------------------------- 13.9/39.5 MB 7.6 MB/s eta 0:00:04
#    -------------- ------------------------- 14.7/39.5 MB 7.2 MB/s eta 0:00:04
#    --------------- ------------------------ 15.5/39.5 MB 6.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.8/39.5 MB 6.6 MB/s eta 0:00:04
#    ------------------ --------------------- 18.6/39.5 MB 6.8 MB/s eta 0:00:04
#    ------------------- -------------------- 19.7/39.5 MB 6.8 MB/s eta 0:00:03
#    ------------------- -------------------- 19.7/39.5 MB 6.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.8/39.5 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 24.9/39.5 MB 7.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/39.5 MB 7.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.3/39.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.5 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 9.4 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.5 MB 19.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 22.6 MB/s eta 0:00:00
# Downloading scipy-1.15.1-cp313-cp313-win_amd64.whl (43.6 MB)
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    
8 MB/s eta 0:00:02
#    ---------------------------------- ---- 182.5/204.1 MB 25.9 MB/s eta 0:00:01
#    ----------------------------------- --- 188.0/204.1 MB 25.9 MB/s eta 0:00:01
#    ------------------------------------ -- 192.4/204.1 MB 25.7 MB/s eta 0:00:01
#    ------------------------------------- - 197.7/204.1 MB 25.7 MB/s eta 0:00:01
#    --------------------------------------- 204.1/204.1 MB 25.9 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------------------------ --------- 4.7/6.2 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 24.4 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp313-cp313-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 29.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 36.9 MB/s eta 0:00:00
# Downloading setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 30.8 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    --------------------------------------- 536.2/536.2 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: pytz, py-cpuinfo, mpmath, tzdata, sympy, setuptools, numpy, networkx, MarkupSafe, fsspec, filelock, scipy, pandas, opencv-python, jinja2, torch, ultralytics-thop, torchvision, seaborn, ultralytics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
# Successfully installed MarkupSafe-3.0.2 filelock-3.17.0 fsspec-2024.12.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.1.1 opencv-python-4.11.0.86 pandas-2.2.3 py-cpuinfo-9.0.0 pytz-2025.1 scipy-1.15.1 seaborn-0.13.2 setuptools-75.8.0 sympy-1.13.1 torch-2.6.0 torchvision-0.21.0 tzdata-2025.1 ultralytics-8.3.70 ultralytics-thop-2.0.14

# %% [markdown]
# # Get Dataset

# %%
# !pip install roboflow
# !pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: roboflow in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (1.1.53)
# Requirement already satisfied: certifi in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2.1.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib->roboflow) (4.55.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (from requests->roboflow) (3.4.1)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: python-dotenv in c:\users\alex\anaconda3\envs\tennis-analysis\lib\site-packages (1.0.1)

# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

# %%
rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
#       2 project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
#       3 version = project.version(6)
#
# File c:\Users\ALEX\anaconda3\envs\tennis-analysis\Lib\site-packages\roboflow\__init__.py:217, in Roboflow.__init__(self, api_key, model_format, notebook)
#     215 self.notebook = notebook
#     216 self.onboarding = False
# --> 217 self.auth()
#
# File c:\Users\ALEX\anaconda3\envs\tennis-analysis\Lib\site-packages\roboflow\__init__.py:220, in Roboflow.auth(self)
#     219 def auth(self):
# --> 220     r = check_key(self.api_key, self.model_format, self.notebook)
#     222     if r == "onboarding":
#     223         self.onboarding = True
#
# File c:\Users\ALEX\anaconda3\envs\tennis-analysis\Lib\site-packages\roboflow\__init__.py:23, in check_key(api_key, model, notebook, num_retries)
#      21 def check_key(api_key, model, notebook, num_retries=0):
#      22     if not isinstance(api_key, str):
# ---> 23         raise RuntimeError(
#      24             "API Key is of Incorrect Type \n Expected Type: " + str(str) + "\n Input Type: " + str(type(api_key))
#      25         )
#      27     if any(c for c in api_key if c.islower()):  # check if any of the api key characters are lowercase
#      28         if api_key in DEMO_KEYS:
#      29             # passthrough for public download of COCO-128 for the time being
#
# RuntimeError: API Key is of Incorrect Type
#  Expected Type: <class 'str'>
#  Input Type: <class 'NoneType'>

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
